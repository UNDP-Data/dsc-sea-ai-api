# %% [markdown]
# ### Import dependencies

# %%
import pandas as pd
import numpy as np
import openai
import json
from dotenv import load_dotenv
import os
from openai import AzureOpenAI
import re
import tiktoken
import time
import spacy
nlp = spacy.load("en_core_web_sm")
import faiss
# Out:
# /Users/davidoluyalegbenga/.pyenv/versions/3.9.6/lib/python3.9/site-packages/spacy/util.py:910: UserWarning: [W095] Model 'en_core_web_sm' (3.0.0) was trained with spaCy v3.0.0 and may not be 100% compatible with the current version (3.7.2). If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)

# %% [markdown]
# ### Load documents data

# %%
with open('../data/documents_all.json', 'r') as json_file:
    data = json.load(json_file)
df = pd.DataFrame(data)
df

# nan_title_rows = df[df['Document Title'].isna()]
# # print(nan_title_rows)

# for index, row in nan_title_rows.iterrows():
#     print(json.dumps(data[index], indent=2))
# Out:
#                   Code     Status Country Name Country Code Category  \
# 0                                         None         None      SEH
# 1                                          USA          USA      SEH
# 2                                         None         None      SEH
# 3                                        China        China      SEH
# 4                                         None         None      SEH
# ..                 ...        ...          ...          ...      ...
# 584   AFG-NRES-2017-PR       None  Afghanistan          AFG     NRES
# 585  AFG-NREP-41365-EN  Completed  Afghanistan          AFG     NREP
# 586   AFG-NRER-2017-EN  Completed  Afghanistan          AFG     NRER
# 587    COL-CPD-2020-SP       None     Colombia          COL      CPD
# 588    COL-CPD-2020-EN       None     Colombia          COL      CPD
#
#     KeyWord to Search                                     Document Title  \
# 0                       Machine learning for a sustainable energy future
# 1                      Clean energy for all? Mapping inequity potenti...
# 2                      Access to clean cooking services in energy and...
# 3                      The asymmetric impacts of artificial intellige...
# 4                                  Is clean cooking affordable? A review
# ..                ...                                                ...
# 584              None  Renewable Energy Strategy for Rural Afghanista...
# 585              None          Afghanistan Rural Renewable Energy Policy
# 586              None   RENEWABLE ENERGY ROADMAP FOR AFGHANISTAN RER2032
# 587              None                                               None
# 588              None                                               None
#
#     Exists?              Publication Date              Publication Year  ...  \
# 0         Y           2023-02-05 00:00:00                          2023  ...
# 1         Y           2023-02-05 00:00:00                          2023  ...
# 2         Y           2023-02-07 00:00:00                          2021  ...
# 3         Y           2023-02-05 00:00:00                          2024  ...
# 4         Y           2023-02-07 00:00:00                          2021  ...
# ..      ...                           ...                           ...  ...
# 584       Y                          2017                          2017  ...
# 585       Y           2013-04-01 00:00:00           2013-04-01 00:00:00  ...
# 586       Y                          2017                          2017  ...
# 587       Y  31 August – 4 September 2020  31 August – 4 September 2020  ...
# 588       Y  31 August – 4 September 2020  31 August – 4 September 2020  ...
#
#     End Year Language                                               Link  \
# 0       2023       EN  https://www.nature.com/articles/s41578-022-004...
# 1       2023       EN  https://www.sciencedirect.com/science/article/...
# 2       2021       EN  https://www.nature.com/articles/s41560-021-009...
# 3       2024       EN  https://www.sciencedirect.com/science/article/...
# 4       2021       EN  https://www.sciencedirect.com/science/article/...
# ..       ...      ...                                                ...
# 584     2027       PR  https://policy.asiapacificenergy.org/sites/def...
# 585     2027       EN  https://cdn.climatepolicyradar.org/navigator/A...
# 586     2032       EN  https://policy.asiapacificenergy.org/sites/def...
# 587     2024       SP  https://www.undp.org/sites/g/files/zskgke326/f...
# 588     2024       EN  https://www.undp.org/sites/g/files/zskgke326/f...
#
#                                                Content  \
# 0    0123456789();: The combustion of fossil fuels,...
# 1    Energy Research & Social Science 108 (2024) 10...
# 2    AnAlysis  1Energy, Climate, and Environment Pr...
# 3    Energy 291 (2024) 130197 Available online  Jan...
# 4    Renewable and Sustainable Energy Reviews 151 (...
# ..                                                 ...
# 584  ناتسناغفا یملاسا یروهمج تاهد فاشکنا   ایحا ترا...
# 585  ISLAMIC REPUBLIC OF AFGHANISTAN MINISTRY OF EN...
# 586  RENEWABLE ENERGY ROADMAP FOR AFGHANISTAN RER20...
# 587  Table of Contents: Distr general: Page:  II Pr...
# 588  Table of Contents:  UNDP within the United Nat...
#
#                                              Thumbnail                 Region  \
# 0                                                 None                 Global
# 1                                                 None         North America
# 2                                                 None                 Global
# 3                                                 None  East Asia and Pacific
# 4                                                 None                   None
# ..                                                 ...                    ...
# 584  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...                    NaN
# 585  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...                    NaN
# 586  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...                    NaN
# 587  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...                    NaN
# 588  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...                    NaN
#
#                                       Journal  \
# 0                                      Nature
# 1            Energy Research & Social Science
# 2                               Nature Energy
# 3                                      Energy
# 4    Renewable and Sustainable Energy Reviews
# ..                                        ...
# 584                                       NaN
# 585                                       NaN
# 586                                       NaN
# 587                                       NaN
# 588                                       NaN
#
#                                                Authors Description  \
# 0    Zhenpeng Yao, Yanwei Lum, Andrew Johnston, Lui...         NaN
# 1    Huiting Chen, Sung-Gheel Jang, Yan Zhang, Yaol...         NaN
# 2    Shonali Pachauri, Miguel Poblete-Cazenave, Ard...         NaN
# 3     Hongwei Zhang, Beixin Fang, Pengwei He, Wang Gao         NaN
# 4                       A Gill-Wiehl, I Ray, D Kammen          NaN
# ..                                                 ...         ...
# 584                                                NaN         NaN
# 585                                                NaN         NaN
# 586                                                NaN         NaN
# 587                                                NaN         NaN
# 588                                                NaN         NaN
#
#     Resolution No
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ..            ...
# 584           NaN
# 585           NaN
# 586           NaN
# 587           NaN
# 588           NaN
#
# [589 rows x 21 columns]

# %% [markdown]
# ### Load enviroments

# %%
load_dotenv()
# Out:
# True

# %% [markdown]
# ### OpenAI API configuration

# %%
 
openai.api_type = "azure"
openai.api_base = os.getenv('OPENAI_API_BASE')
openai.api_version = "2023-05-15"
openai.api_key = os.getenv('OPENAI_API_KEY')
openai_deployment = "sdgi-gpt-35-turbo-16k"

client = AzureOpenAI(
  api_key = os.getenv("api_key_azure"),  
  api_version = os.getenv("api_version"),
  azure_endpoint =os.getenv("AZURE_OPENAI_ENDPOINT") 
)
encoding = tiktoken.get_encoding('cl100k_base')
embedding_model = os.getenv("USER_QUERY_EMBEDDING_ENGINE")

# %% [markdown]
# ### Embedding Processings

# %%
def create_embedding(row):
    time.sleep(3)
    input_text = row['Content'].replace("\n", " ")
    input_text = re.sub(r'\s+', ' ', input_text)
    encodings = encoding.encode(input_text)
    length = len(encodings)
    if len(encodings) > 8090:
        input_text = encoding.decode(encodings[:8090])
    embedding = client.embeddings.create( 
        input=input_text ,model= embedding_model
    ).data[0].embedding
    
    return length, embedding

df['token_length'], df['Embedding'] = zip(*df.apply(lambda row: create_embedding(row), axis=1))

# %%
def cut_context(row):
    if row['token_length'] < 15000:
        return row['Content']
    else:
        text = row['Content'].replace("\n", " ")
        text =  re.sub(r'\s+', ' ', text)
        encodings = encoding.encode(text)
        cut = encodings[0:15000]
        decodings =  encoding.decode(cut)
        return decodings

df['content_cut'] = df.apply(lambda row:cut_context(row), axis= 1)

print(df['content_cut'])
# Out:
# 0      0123456789();: The combustion of fossil fuels,...
# 1      Energy Research & Social Science 108 (2024) 10...
# 2      AnAlysis  1Energy, Climate, and Environment Pr...
# 3      Energy 291 (2024) 130197 Available online Janu...
# 4      Renewable and Sustainable Energy Reviews 151 (...
#                              ...
# 584    ناتسناغفا یملاسا یروهمج تاهد فاشکنا ایحا ترازو...
# 585    ISLAMIC REPUBLIC OF AFGHANISTAN MINISTRY OF EN...
# 586    RENEWABLE ENERGY ROADMAP FOR AFGHANISTAN RER20...
# 587    Table of Contents: Distr general: Page:  II Pr...
# 588    Table of Contents:  UNDP within the United Nat...
# Name: content_cut, Length: 589, dtype: object

# %%
# save embeddings 
df[df['Language'] == 'EN'].to_pickle('df_embed_EN_All_V3.pkl')

# %% [markdown]
# ### Testing the model

# %%
df = pd.read_pickle('../models/df_embed_EN_All_V2.pkl')
df

# %%
user_query = 'Give me a summary of the goals UNDP wants to achieve in 10 years and the energy plans for Philippines'

# %%
def find_mentioned_countries(text):
    doc = nlp(text)
    countries = set()
    
    for ent in doc.ents:
        if ent.label_ == "GPE":  # GPE stands for "Geopolitical Entity"
            countries.add(ent.text)
    
    return list(countries)

#Example 
# mentioned_countries = find_mentioned_countries(user_query)
# mentioned_countries

# %%
def filter_country(user_query):
    country = find_mentioned_countries(user_query)[0]
    print(country)
    return df[df['Country Name'] == country]


#Example 
# filtered_country = filter_country(user_query)
# filtered_country

# %%
def search_embeddings(user_query):
    df_filtered = filter_country(user_query)
    length = len(df_filtered.head())
    filtered_embeddings_arrays = np.array(list(df_filtered['Embedding']))
    index = faiss.IndexFlatIP(filtered_embeddings_arrays.shape[1]) 
    index.add(filtered_embeddings_arrays)
    
    user_query_embedding = client.embeddings.create( 
        input=user_query ,model= embedding_model
    ).data[0].embedding

    if length > 5:
        k = 5
    else:
        k = length
    distances, indices = index.search(np.array([user_query_embedding]), k)
    return df_filtered, distances, indices


#Example 
# search_embedding = search_embeddings(user_query)
# search_embedding

# %%
def get_answer(user_question, content):
    system_prompt = "You are a system that answer user questions based on excerpts from PDF documents that are provided for context. You must only answer the question if the answer can be found in the provided context. Do not make up the answer, and if you cannot find the answer in the context just say that you cannot find the answer"
    messages = [
        {'role': 'system', 'content': system_prompt},
        {'role': 'user', 'content': user_question},
        {'role': 'user', 'content': content},
    ]
        
    response_entities = openai.chat.completions.create(
                    model=openai_deployment,
                    temperature=0,
                    messages=messages,
        )
    response = response_entities.choices[0].message.content

    return response

# %%
def response_generating(user_query):
    df, distances, indices = search_embeddings(user_query)
    dis = distances[0][::-1]
    ind = indices[0][::-1]
    for i in range(len(dis)):
        content = df.iloc[ind[i]]['content_cut']
        print("Searching document {} ({})...".format(df.iloc[ind[i]]['Document Title'], df.iloc[ind[i]]['Link']))
        response = get_answer(user_query, content)
        answer = response['choices'][0]['message']['content']
        
        not_found_phrases = ['not mention', 'not mentioned', 'I did not find', 'not found', 'no information', 'not contain', 'cannot be found', 'no mention']
        if any(phrase.lower() in answer.lower() for phrase in not_found_phrases):
            print('Answer not found in this document')
            continue
        else:
            return answer
