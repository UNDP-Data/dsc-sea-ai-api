# %% [markdown]
# ### Import dependencies

# %%
import pandas as pd
import numpy as np
import openai
import json
from dotenv import load_dotenv
import os
from openai import AzureOpenAI
import re
import tiktoken
import time
import spacy
nlp = spacy.load("en_core_web_sm")
import faiss
# Out:
# /Users/davidoluyalegbenga/.pyenv/versions/3.9.6/lib/python3.9/site-packages/spacy/util.py:910: UserWarning: [W095] Model 'en_core_web_sm' (3.0.0) was trained with spaCy v3.0.0 and may not be 100% compatible with the current version (3.7.2). If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)

# %% [markdown]
# ### Load documents data

# %%
with open('../data/documents_all.json', 'r') as json_file:
    data = json.load(json_file)
df = pd.DataFrame(data)
df

# nan_title_rows = df[df['Document Title'].isna()]
# # print(nan_title_rows)

# for index, row in nan_title_rows.iterrows():
#     print(json.dumps(data[index], indent=2))
# Out:
#                   Code     Status Country Name Country Code      Category  \
# 0                                                            Publications
# 1                                                            Publications
# 2                                                            Publications
# 3                                                            Publications
# 4                                                            Publications
# ..                 ...        ...          ...          ...           ...
# 666   AFG-NRES-2017-PR       None  Afghanistan          AFG          NRES
# 667  AFG-NREP-41365-EN  Completed  Afghanistan          AFG          NREP
# 668   AFG-NRER-2017-EN  Completed  Afghanistan          AFG          NRER
# 669    COL-CPD-2020-SP       None     Colombia          COL           CPD
# 670    COL-CPD-2020-EN       None     Colombia          COL           CPD
#
#     KeyWord to Search                                     Document Title  \
# 0                None                         Credible pathways to 1.5°C
# 1                None  Global Hydrogen Trade to Meet the 1.5°C Climat...
# 2                None  Technology and Innovation Pathways for Zero-ca...
# 3                None  The potential of digital business models in th...
# 4                None          Security of Clean Energy Transitions 2022
# ..                ...                                                ...
# 666              None  Renewable Energy Strategy for Rural Afghanista...
# 667              None          Afghanistan Rural Renewable Energy Policy
# 668              None   RENEWABLE ENERGY ROADMAP FOR AFGHANISTAN RER2032
# 669              None                                               None
# 670              None                                               None
#
#     Exists?              Publication Date              Publication Year  ...  \
# 0         Y                          2023                                ...
# 1         Y                          2022                                ...
# 2         Y                          2022                                ...
# 3         Y                          2022                                ...
# 4         Y                          2022                                ...
# ..      ...                           ...                           ...  ...
# 666       Y                          2017                          2017  ...
# 667       Y           2013-04-01 00:00:00           2013-04-01 00:00:00  ...
# 668       Y                          2017                          2017  ...
# 669       Y  31 August – 4 September 2020  31 August – 4 September 2020  ...
# 670       Y  31 August – 4 September 2020  31 August – 4 September 2020  ...
#
#     End Year Language                                               Link  \
# 0                  EN  https://www.iea.org/reports/credible-pathways-...
# 1                  EN  https://www.irena.org/Publications/2022/Apr/Gl...
# 2                  EN  https://www.iea.org/reports/technology-and-inn...
# 3                  EN  https://www.iea.org/articles/the-potential-of-...
# 4                  EN  https://www.iea.org/reports/security-of-clean-...
# ..       ...      ...                                                ...
# 666     2027       PR  https://policy.asiapacificenergy.org/sites/def...
# 667     2027       EN  https://cdn.climatepolicyradar.org/navigator/A...
# 668     2032       EN  https://policy.asiapacificenergy.org/sites/def...
# 669     2024       SP  https://www.undp.org/sites/g/files/zskgke326/f...
# 670     2024       EN  https://www.undp.org/sites/g/files/zskgke326/f...
#
#                                                Content Description Journal  \
# 0    Credible pathways to 1.5°C – Analysis - IEA IE...        None
# 1    Global Hydrogen Trade to Meet the 1.5°C Climat...        None
# 2    Technology and Innovation Pathways for Zero-ca...        None
# 3    The Potential of Digital Business Models in th...        None
# 4    Security of Clean Energy Transitions 2022 – An...        None
# ..                                                 ...         ...     ...
# 666  ناتسناغفا یملاسا یروهمج تاهد فاشکنا   ایحا ترا...         NaN     NaN
# 667  ISLAMIC REPUBLIC OF AFGHANISTAN MINISTRY OF EN...         NaN     NaN
# 668  RENEWABLE ENERGY ROADMAP FOR AFGHANISTAN RER20...         NaN     NaN
# 669  Table of Contents: Distr general: Page:  II Pr...         NaN     NaN
# 670  Table of Contents:  UNDP within the United Nat...         NaN     NaN
#
#                                              Thumbnail Resolution No Region  \
# 0                                                                NaN    NaN
# 1                                                                NaN    NaN
# 2                                                                NaN    NaN
# 3                                                                NaN    NaN
# 4                                                                NaN    NaN
# ..                                                 ...           ...    ...
# 666  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...           NaN    NaN
# 667  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...           NaN    NaN
# 668  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...           NaN    NaN
# 669  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...           NaN    NaN
# 670  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...           NaN    NaN
#
#     Authors
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# ..      ...
# 666     NaN
# 667     NaN
# 668     NaN
# 669     NaN
# 670     NaN
#
# [671 rows x 21 columns]

# %% [markdown]
# ### Load enviroments

# %%
load_dotenv()
# Out:
# True

# %% [markdown]
# ### OpenAI API configuration

# %%
 
openai.api_type = "azure"
openai.api_base = os.getenv('OPENAI_API_BASE')
openai.api_version = "2023-05-15"
openai.api_key = os.getenv('OPENAI_API_KEY')
openai_deployment = "sdgi-gpt-35-turbo-16k"

client = AzureOpenAI(
  api_key = os.getenv("api_key_azure"),  
  api_version = os.getenv("api_version"),
  azure_endpoint =os.getenv("AZURE_OPENAI_ENDPOINT") 
)
encoding = tiktoken.get_encoding('cl100k_base')
embedding_model = os.getenv("USER_QUERY_EMBEDDING_ENGINE")

# %% [markdown]
# ### Embedding Processings

# %%
def create_embedding(row):
    time.sleep(3)
    input_text = row['Content'].replace("\n", " ")
    input_text = re.sub(r'\s+', ' ', input_text)
    encodings = encoding.encode(input_text)
    length = len(encodings)
    if len(encodings) > 8090:
        input_text = encoding.decode(encodings[:8090])
    embedding = client.embeddings.create( 
        input=input_text ,model= embedding_model
    ).data[0].embedding
    
    return length, embedding

df['token_length'], df['Embedding'] = zip(*df.apply(lambda row: create_embedding(row), axis=1))

# %%
def cut_context(row):
    if row['token_length'] < 15000:
        return row['Content']
    else:
        text = row['Content'].replace("\n", " ")
        text =  re.sub(r'\s+', ' ', text)
        encodings = encoding.encode(text)
        cut = encodings[0:15000]
        decodings =  encoding.decode(cut)
        return decodings

df['content_cut'] = df.apply(lambda row:cut_context(row), axis= 1)

print(df['content_cut'])
# Out:
# 0      Credible pathways to 1.5°C – Analysis - IEA IE...
# 1      Global Hydrogen Trade to Meet the 1.5°C Climat...
# 2      Technology and Innovation Pathways for Zero-ca...
# 3      The Potential of Digital Business Models in th...
# 4      Security of Clean Energy Transitions 2022 – An...
#                              ...
# 666    ناتسناغفا یملاسا یروهمج تاهد فاشکنا ایحا ترازو...
# 667    ISLAMIC REPUBLIC OF AFGHANISTAN MINISTRY OF EN...
# 668    RENEWABLE ENERGY ROADMAP FOR AFGHANISTAN RER20...
# 669    Table of Contents: Distr general: Page:  II Pr...
# 670    Table of Contents:  UNDP within the United Nat...
# Name: content_cut, Length: 671, dtype: object

# %%
# save embeddings 
df[df['Language'] == 'EN'].to_pickle('df_embed_EN_All_V2.pkl')

# %% [markdown]
# ### Testing the model

# %%
df = pd.read_pickle('../models/df_embed_EN_All_V2.pkl')
df

# %%
user_query = 'Give me a summary of the goals UNDP wants to achieve in 10 years and the energy plans for Philippines'

# %%
def find_mentioned_countries(text):
    doc = nlp(text)
    countries = set()
    
    for ent in doc.ents:
        if ent.label_ == "GPE":  # GPE stands for "Geopolitical Entity"
            countries.add(ent.text)
    
    return list(countries)

#Example 
# mentioned_countries = find_mentioned_countries(user_query)
# mentioned_countries

# %%
def filter_country(user_query):
    country = find_mentioned_countries(user_query)[0]
    print(country)
    return df[df['Country Name'] == country]


#Example 
# filtered_country = filter_country(user_query)
# filtered_country

# %%
def search_embeddings(user_query):
    df_filtered = filter_country(user_query)
    length = len(df_filtered.head())
    filtered_embeddings_arrays = np.array(list(df_filtered['Embedding']))
    index = faiss.IndexFlatIP(filtered_embeddings_arrays.shape[1]) 
    index.add(filtered_embeddings_arrays)
    
    user_query_embedding = client.embeddings.create( 
        input=user_query ,model= embedding_model
    ).data[0].embedding

    if length > 5:
        k = 5
    else:
        k = length
    distances, indices = index.search(np.array([user_query_embedding]), k)
    return df_filtered, distances, indices


#Example 
# search_embedding = search_embeddings(user_query)
# search_embedding

# %%
def get_answer(user_question, content):
    system_prompt = "You are a system that answer user questions based on excerpts from PDF documents that are provided for context. You must only answer the question if the answer can be found in the provided context. Do not make up the answer, and if you cannot find the answer in the context just say that you cannot find the answer"
    messages = [
        {'role': 'system', 'content': system_prompt},
        {'role': 'user', 'content': user_question},
        {'role': 'user', 'content': content},
    ]
        
    response_entities = openai.chat.completions.create(
                    model=openai_deployment,
                    temperature=0,
                    messages=messages,
        )
    response = response_entities.choices[0].message.content

    return response

# %%
def response_generating(user_query):
    df, distances, indices = search_embeddings(user_query)
    dis = distances[0][::-1]
    ind = indices[0][::-1]
    for i in range(len(dis)):
        content = df.iloc[ind[i]]['content_cut']
        print("Searching document {} ({})...".format(df.iloc[ind[i]]['Document Title'], df.iloc[ind[i]]['Link']))
        response = get_answer(user_query, content)
        answer = response['choices'][0]['message']['content']
        
        not_found_phrases = ['not mention', 'not mentioned', 'I did not find', 'not found', 'no information', 'not contain', 'cannot be found', 'no mention']
        if any(phrase.lower() in answer.lower() for phrase in not_found_phrases):
            print('Answer not found in this document')
            continue
        else:
            return answer
