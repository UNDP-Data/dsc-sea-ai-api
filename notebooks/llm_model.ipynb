# %% [markdown]
# ### Import dependencies

# %%
import pandas as pd
import numpy as np
import openai
import json
from dotenv import load_dotenv
import os
from openai import AzureOpenAI
import re
import tiktoken
import time
import spacy
nlp = spacy.load("en_core_web_sm")
import faiss
# Out:
# /Users/davidoluyalegbenga/.pyenv/versions/3.9.6/lib/python3.9/site-packages/spacy/util.py:910: UserWarning: [W095] Model 'en_core_web_sm' (3.0.0) was trained with spaCy v3.0.0 and may not be 100% compatible with the current version (3.7.2). If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)

# %% [markdown]
# ### Load documents data

# %%
with open('../data/documents_all.json', 'r') as json_file:
    data = json.load(json_file)
df = pd.DataFrame(data)
df

# nan_title_rows = df[df['Document Title'].isna()]
# # print(nan_title_rows)

# for index, row in nan_title_rows.iterrows():
#     print(json.dumps(data[index], indent=2))
# Out:
#                   Code     Status Country Name Country Code Category  \
# 0                                         None         None      SEH
# 1                                         None         None      SEH
# 2                                         None         None      SEH
# 3                                         None         None      SEH
# 4                                         None         None      SEH
# ..                 ...        ...          ...          ...      ...
# 669   AFG-NRES-2017-PR       None  Afghanistan          AFG     NRES
# 670  AFG-NREP-41365-EN  Completed  Afghanistan          AFG     NREP
# 671   AFG-NRER-2017-EN  Completed  Afghanistan          AFG     NRER
# 672    COL-CPD-2020-SP       None     Colombia          COL      CPD
# 673    COL-CPD-2020-EN       None     Colombia          COL      CPD
#
#     KeyWord to Search                                     Document Title  \
# 0                       Machine learning for a sustainable energy future
# 1                      Market Barriers to Clean Cooking Fuels in Sub-...
# 2                      Financial Development, Clean Energy, and Human...
# 3                      Access to clean cooking services in energy and...
# 4                      The evolving just transition: definitions, con...
# ..                ...                                                ...
# 669              None  Renewable Energy Strategy for Rural Afghanista...
# 670              None          Afghanistan Rural Renewable Energy Policy
# 671              None   RENEWABLE ENERGY ROADMAP FOR AFGHANISTAN RER2032
# 672              None                                               None
# 673              None                                               None
#
#     Exists?              Publication Date              Publication Year  \
# 0         Y           2023-02-05 00:00:00                          2023
# 1         Y           2023-02-07 00:00:00                          2008
# 2         Y           2023-02-07 00:00:00                          2021
# 3         Y           2023-02-07 00:00:00                          2021
# 4         Y           2023-02-05 00:00:00                          2023
# ..      ...                           ...                           ...
# 669       Y                          2017                          2017
# 670       Y           2013-04-01 00:00:00           2013-04-01 00:00:00
# 671       Y                          2017                          2017
# 672       Y  31 August – 4 September 2020  31 August – 4 September 2020
# 673       Y  31 August – 4 September 2020  31 August – 4 September 2020
#
#     Start Year End Year Language  \
# 0         2023     2023       EN
# 1         2008     2008       EN
# 2         2021     2021       EN
# 3         2021     2021       EN
# 4         2023     2023       EN
# ..         ...      ...      ...
# 669       2017     2027       PR
# 670       2017     2027       EN
# 671       2017     2032       EN
# 672       2021     2024       SP
# 673       2021     2024       EN
#
#                                                   Link  \
# 0    https://www.nature.com/articles/s41578-022-004...
# 1    https://www.sei.org/publications/market-barrie...
# 2            https://www.mdpi.com/1996-1073/14/13/3763
# 3    https://www.nature.com/articles/s41560-021-009...
# 4    https://iopscience.iop.org/article/10.1088/263...
# ..                                                 ...
# 669  https://policy.asiapacificenergy.org/sites/def...
# 670  https://cdn.climatepolicyradar.org/navigator/A...
# 671  https://policy.asiapacificenergy.org/sites/def...
# 672  https://www.undp.org/sites/g/files/zskgke326/f...
# 673  https://www.undp.org/sites/g/files/zskgke326/f...
#
#                                                Content  \
# 0    Machine learning for a sustainable energy futu...
# 1    Market Barriers to Clean Cooking Fuels in Sub-...
# 2    Energies | Free Full-Text | Financial Developm...
# 3    Access to clean cooking services in energy and...
# 4    The evolving just transition: definitions, con...
# ..                                                 ...
# 669  ناتسناغفا یملاسا یروهمج تاهد فاشکنا   ایحا ترا...
# 670  ISLAMIC REPUBLIC OF AFGHANISTAN MINISTRY OF EN...
# 671  File Name: AFG-NRER-2017-EN\nYear: 2017\nCount...
# 672  Table of Contents: Distr general: Page:  II Pr...
# 673  Table of Contents:  UNDP within the United Nat...
#
#                          Region                 Journal  \
# 0                        Global                  Nature
# 1           Sub-Saharan Africa                     None
# 2    Latin America & Caribbean                Energies
# 3                        Global           Nature Energy
# 4           Sub-Saharan Africa   Environmental Research
# ..                          ...                     ...
# 669                         NaN                     NaN
# 670                         NaN                     NaN
# 671                         NaN                     NaN
# 672                         NaN                     NaN
# 673                         NaN                     NaN
#
#                                                Authors Description  \
# 0    Zhenpeng Yao, Yanwei Lum, Andrew Johnston, Lui...         NaN
# 1                             Schlag, N., Zuzarte, F.          NaN
# 2    Pablo Ponce,José Álvarez-García ,Johanna Medin...         NaN
# 3    Shonali Pachauri, Miguel Poblete-Cazenave, Ard...         NaN
# 4                               M Otlhogile, R Shirley         NaN
# ..                                                 ...         ...
# 669                                                NaN         NaN
# 670                                                NaN         NaN
# 671                                                NaN         NaN
# 672                                                NaN         NaN
# 673                                                NaN         NaN
#
#     Resolution No
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ..            ...
# 669           NaN
# 670           NaN
# 671           NaN
# 672           NaN
# 673           NaN
#
# [674 rows x 20 columns]

# %% [markdown]
# ### Load enviroments

# %%
load_dotenv()
# Out:
# True

# %% [markdown]
# ### OpenAI API configuration

# %%
 
openai.api_type = "azure"
openai.api_base = os.getenv('OPENAI_API_BASE')
openai.api_version = "2023-05-15"
openai.api_key = os.getenv('OPENAI_API_KEY')
openai_deployment = "sdgi-gpt-35-turbo-16k"

client = AzureOpenAI(
  api_key = os.getenv("api_key_azure"),  
  api_version = os.getenv("api_version"),
  azure_endpoint =os.getenv("AZURE_OPENAI_ENDPOINT") 
)
encoding = tiktoken.get_encoding('cl100k_base')
embedding_model = os.getenv("USER_QUERY_EMBEDDING_ENGINE")

# %% [markdown]
# ### Embedding Processings

# %%
def create_embedding(row):
    time.sleep(3)
    input_text = row['Content'].replace("\n", " ")
    input_text = re.sub(r'\s+', ' ', input_text)
    encodings = encoding.encode(input_text)
    length = len(encodings)
    if len(encodings) > 8090:
        input_text = encoding.decode(encodings[:8090])
    embedding = client.embeddings.create( 
        input=input_text ,model= embedding_model
    ).data[0].embedding
    
    return length, embedding

df['token_length'], df['Embedding'] = zip(*df.apply(lambda row: create_embedding(row), axis=1))

# %%
def cut_context(row):
    if row['token_length'] < 15000:
        return row['Content']
    else:
        text = row['Content'].replace("\n", " ")
        text =  re.sub(r'\s+', ' ', text)
        encodings = encoding.encode(text)
        cut = encodings[0:15000]
        decodings =  encoding.decode(cut)
        return decodings

df['content_cut'] = df.apply(lambda row:cut_context(row), axis= 1)

print(df['content_cut'])
# Out:
# 0      Machine learning for a sustainable energy futu...
# 1      Market Barriers to Clean Cooking Fuels in Sub-...
# 2      Energies | Free Full-Text | Financial Developm...
# 3      Access to clean cooking services in energy and...
# 4      The evolving just transition: definitions, con...
#                              ...
# 669    ناتسناغفا یملاسا یروهمج تاهد فاشکنا ایحا ترازو...
# 670    ISLAMIC REPUBLIC OF AFGHANISTAN MINISTRY OF EN...
# 671    File Name: AFG-NRER-2017-EN Year: 2017 Country...
# 672    Table of Contents: Distr general: Page:  II Pr...
# 673    Table of Contents:  UNDP within the United Nat...
# Name: content_cut, Length: 674, dtype: object

# %%
# save embeddings 
df[df['Language'] == 'EN'].to_pickle('df_embed_EN_All_V1.pkl')

# %% [markdown]
# ### Testing the model

# %%
df = pd.read_pickle('../models/df_embed_EN_All_V1.pkl')
df

# %%
user_query = 'Give me a summary of the goals UNDP wants to achieve in 10 years and the energy plans for Philippines'

# %%
def find_mentioned_countries(text):
    doc = nlp(text)
    countries = set()
    
    for ent in doc.ents:
        if ent.label_ == "GPE":  # GPE stands for "Geopolitical Entity"
            countries.add(ent.text)
    
    return list(countries)

#Example 
# mentioned_countries = find_mentioned_countries(user_query)
# mentioned_countries

# %%
def filter_country(user_query):
    country = find_mentioned_countries(user_query)[0]
    print(country)
    return df[df['Country Name'] == country]


#Example 
# filtered_country = filter_country(user_query)
# filtered_country

# %%
def search_embeddings(user_query):
    df_filtered = filter_country(user_query)
    length = len(df_filtered.head())
    filtered_embeddings_arrays = np.array(list(df_filtered['Embedding']))
    index = faiss.IndexFlatIP(filtered_embeddings_arrays.shape[1]) 
    index.add(filtered_embeddings_arrays)
    
    user_query_embedding = client.embeddings.create( 
        input=user_query ,model= embedding_model
    ).data[0].embedding

    if length > 5:
        k = 5
    else:
        k = length
    distances, indices = index.search(np.array([user_query_embedding]), k)
    return df_filtered, distances, indices


#Example 
# search_embedding = search_embeddings(user_query)
# search_embedding

# %%
def get_answer(user_question, content):
    system_prompt = "You are a system that answer user questions based on excerpts from PDF documents that are provided for context. You must only answer the question if the answer can be found in the provided context. Do not make up the answer, and if you cannot find the answer in the context just say that you cannot find the answer"
    messages = [
        {'role': 'system', 'content': system_prompt},
        {'role': 'user', 'content': user_question},
        {'role': 'user', 'content': content},
    ]
        
    response_entities = openai.chat.completions.create(
                    model=openai_deployment,
                    temperature=0,
                    messages=messages,
        )
    response = response_entities.choices[0].message.content

    return response

# %%
def response_generating(user_query):
    df, distances, indices = search_embeddings(user_query)
    dis = distances[0][::-1]
    ind = indices[0][::-1]
    for i in range(len(dis)):
        content = df.iloc[ind[i]]['content_cut']
        print("Searching document {} ({})...".format(df.iloc[ind[i]]['Document Title'], df.iloc[ind[i]]['Link']))
        response = get_answer(user_query, content)
        answer = response['choices'][0]['message']['content']
        
        not_found_phrases = ['not mention', 'not mentioned', 'I did not find', 'not found', 'no information', 'not contain', 'cannot be found', 'no mention']
        if any(phrase.lower() in answer.lower() for phrase in not_found_phrases):
            print('Answer not found in this document')
            continue
        else:
            return answer
